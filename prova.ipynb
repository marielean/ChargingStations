# %%
import networkx as nx
import utility_functions as uf
import matplotlib.pyplot as plt

# %%
# Create a new directed graph G
G = nx.Graph()

# Add edges (implicitely adds nodes)
G.add_edge('A', 'B', {'weight': 1})
G.add_edge('A', 'C', {'weight': 2})
G.add_edge('B', 'D', {'weight': 3})
G.add_edge('B', 'E', {'weight': 4})
G.add_edge('C', 'F', {'weight': 5})
G.add_edge('C', 'G', {'weight': 6})

# Draw the graph
uf.draw_tree(G)

# %%
# Create a new undirected graph G
G = nx.Graph()

# Add edges (implicitely adds nodes)
G.add_edge('A', 'B')
G.add_edge('A', 'C')
G.add_edge('B', 'D')
G.add_edge('B', 'E')
G.add_edge('C', 'F')
G.add_edge('C', 'G')

# Draw the graph
nx.draw(G, with_labels=True)
plt.show()

# %%
#Esempio di creazione grafo

G = nx.Graph()

nodes_list = [(1, {'color': 'blue'}), (2, {'color': 'red'}), (3, {'color': 'green'})]

G.add_nodes_from(nodes_list)


nx.draw(G)

# %%
G = nx.binomial_tree(5)

nx.draw(G)

# %%
G = nx.balanced_tree(2, 3)

nx.draw(G)

# %%
''' 
PROVE DI FUNZIONI DI LIBRERIA:
    - add_edges_from()
    - add_edge()
    - add_node()
    - add_nodes_from()
'''
G = nx.Graph()

G.add_edges_from([(1, 3), (1,2), (3, 'c')])
G.add_node(1, time='5pm', location='home')
G.add_edge(1, 2)
G.add_node("spam")        # adds node "spam"
G.add_nodes_from("ciaone")  # adds 4 nodes: 's', 'p', 'a', 'm'
G.add_edge(3, 'm')

nx.draw(G, with_labels=True)

print("nodes: ", G.nodes())
print("edges: ", G.edges())
# Out:
# nodes:  [1, 3, 2, 'c', 'spam', 'i', 'a', 'o', 'n', 'e', 'm']
# edges:  [(1, 3), (1, 2), (3, 'c'), (3, 'm')]
